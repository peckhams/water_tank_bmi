# %% [markdown]
# ## Water Tank Example for the Basic Modeling Interface (BMI)

# %% [markdown]
# ### A Water Tank Drained by Gravity and Filled by Rainfall: <br> A Simple Example of Component-based Modeling

# %% [markdown]
# This example was constructed as a simple example based on the control volume concept in order to illustrate the basic principles of plug-and-play, or component-based modeling. (The control volume concept lies at the core of fluid dynamics and all conservation laws.) These principles are used by most modern, model coupling frameworks such as CSDMS (Community Surface Dynamics Modeling System) and OMS (Object Modeling System).
#
# This example has a simple set of state variables, h(t), V (t), v(t) and Q\_out(t) that describe the state of the system as a function of time. It also has a simple set of configuration parameters that are fixed at the start of a model run (in the model’s configuration file) and serve to set up the problem. These are A\_top, A\_out and h\_0.
#
# The rainfall rate, R, can be viewed as a driver or forcing variable for the problem, which could be obtained from another model component that is coupled to the water tank model component, or read from a data file. This example is simpler than typical computational models in that there is an analytic solution, so numerical methods of solving differential equations, which can become unstable, are not needed. Also, it doesn’t require a discretization of space, so there is no spatial grid, which would introduce additional complexity.

# %% [markdown]
# <b>References</b> <br>
# Peckham, S.D. (2016) A water tank drained by gravity and filled by rainfall: A simple example of component-based modeling,

# %%
import water_tank_bmi_2021 as water_tank
water_tank.test_tank_model()
# Out:
# Reading file = tank_info.cfg
#    number of lines = 6
#
# Reading file = tank_info.cfg
#    data format = key_value
#
# Reading file = tank_info.cfg
#    dt         = 4000.0 [sec]
#    n_steps    = 300
#    init_depth = 1.0 [m]
#    top_radius = 20.0 [m]
#    top_area   = 1256.6370614359173 [m2]
#    out_radius = 0.05 [m]
#    out_speed  = 2.2147234590350102 [m/s]
#    depth      = 1.0 [m]
#    volume     = 1256.6370614359173 [m3]
#    out_area   = 0.007853981633974483 [m2]
#    rain_file  = rain_data.txt
#
# Reading file = rain_data.txt
#    number of lines = 300
#
# Reading file = rain_data.txt
#    data format = numeric
#
# Reading file = rain_data.txt
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9890763579685691 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9784559569133902 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9681319885370069 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9580977249630084 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9483465207067525 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9388718145408467 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.92966713125285 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9207260832930183 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9120423723102774 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.9036097905749745 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8954222222873239 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.887473644770828 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8797581295503094 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8722698433145493 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8650030487638665 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8579521053433116 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8511114698624689 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.844475697003175 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8380394397167533 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8317974495126483 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8257445766406033 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8198757701687747 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.814186077960399 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8086706465518416 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.8033247209350434 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7981436442475491 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7931228573734564 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7882578984587494 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7835444023445963 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7789780999222804 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7745548174135072 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7702704755798871 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7661210888654325 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7621027644759247 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.758211701399019 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7544441893689398 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7507966077796002 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7472654245499398 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7438471949452266 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.740538560358011 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7373362470523469 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7342370648748155 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7312379059358021 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7283357432643777 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7255276294400378 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7228106952044424 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7201821480561899 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7176392708315419 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7151794202738978 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7128000255946954 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7104985870282934 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7082726743832681 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7061199255924306 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7040380452637502 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7020248032342463 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.7000780331287894 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6981956309256317 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6963755535303727 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.694615817359947 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6929144969381106 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.691269723503794 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6896796836335823 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6881426178794785 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6866568194230109 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6852206327466472 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6838324523233849 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6824907213253021 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6811939303517687 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6799406161779324 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6787293605240269 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6775587888459654 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6764275691476253 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6753344108151537 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6742780634735731 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6732573158658974 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6722709947549234 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6713179638478071 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6703971227434872 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6695074059029745 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6686477816424858 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6678172511493585 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6670148475206525 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6662396348243081 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6654907071827014 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6647671878784116 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6640682284819874 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6633930080014782 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6627407320534757 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6621106320553921 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6615019644386836 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6609140098827156 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.6603460725689517 [meters]
# --------------------------------------
# rain_rate = 40.0  [mmph]
# depth     = 0.